# %%
import json
import numpy as np
import parsers

# %%
food_businesses = parsers.get_food_business()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sijing/Downloads/Hypergraph/Yelp/parsers.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sijing/Downloads/Hypergraph/Yelp/parsers.ipynb#ch0000013?line=0'>1</a> food_businesses = parsers.get_food_business()
#
# File ~/Downloads/Hypergraph/Yelp/parsers.py:117, in get_food_business()
#     <a href='file:///Users/sijing/Downloads/Hypergraph/Yelp/parsers.py?line=108'>109</a> food = {
#     <a href='file:///Users/sijing/Downloads/Hypergraph/Yelp/parsers.py?line=109'>110</a>     'original_id': [],
#     <a href='file:///Users/sijing/Downloads/Hypergraph/Yelp/parsers.py?line=110'>111</a>     'id': [],
#     <a href='file:///Users/sijing/Downloads/Hypergraph/Yelp/parsers.py?line=111'>112</a>     'latitude': [],
# ...

# %%
reviews = []
with open('yelp_academic_dataset_review.json') as f:
    for line in f:
        reviews.append(json.loads(line))
len(reviews)

review_ids = []
review_user_ids = []
review_business_ids = []
review_starss = []
review_usefuls = []
review_funnys = []
review_cools = []
texts = []
dates = []

for rev in reviews:
    review_ids.append(rev['review_id'])
    review_user_ids.append(rev['user_id'])
    review_business_ids.append(rev['business_id'])
    review_starss.append(rev['stars'])
    review_usefuls.append(rev['useful'])
    review_funnys.append(rev['funny'])
    review_cools.append(rev['cool'])
    texts.append(rev['text'])
    dates.append(rev['date'])

# %%
businesses = []
with open('yelp_academic_dataset_business.json') as f:
    for line in f:
        businesses.append(json.loads(line))

business_ids = []
names = []
addresses = []
cities = []
states = []
postal_codes = []
latitudes = []
longtitudes = []
business_starss = []
business_review_counts = []
business_is_opens = []
business_attributes = []
business_categories = []
business_hours = []

'''for bus in businesses:
    business_ids.append(bus['business_id'])
    names.append(bus['name'])
    addresses.append(bus['address'])
    cities.append(bus['city'])
    states.append(bus['state'])
    postal_codes.append(bus['postal_code'])
    latitudes.append(bus['latitude'])
    longtitudes.append(bus['longitude'])
    business_starss.append(bus['stars'])
    business_review_counts.append(bus['review_count'])
    business_is_opens.append(bus['is_open'])
    business_attributes.append(bus['attributes'])
    business_categories.append(bus['categories'])
    business_hours.append(bus['hours'])'''
# Out:
# "for bus in businesses:\n    business_ids.append(bus['business_id'])\n    names.append(bus['name'])\n    addresses.append(bus['address'])\n    cities.append(bus['city'])\n    states.append(bus['state'])\n    postal_codes.append(bus['postal_code'])\n    latitudes.append(bus['latitude'])\n    longtitudes.append(bus['longitude'])\n    business_starss.append(bus['stars'])\n    business_review_counts.append(bus['review_count'])\n    business_is_opens.append(bus['is_open'])\n    business_attributes.append(bus['attributes'])\n    business_categories.append(bus['categories'])\n    business_hours.append(bus['hours'])"

# %%
users = []
with open('yelp_academic_dataset_user.json') as f:
    for line in f:
        users.append(json.loads(line))
        
user_ids = []
names = []
review_counts = []
yelping_sinces = []
usefuls = []
funnys = []
cools = []
elites = []
friendss = []

#len(users)
#users[1]

for user in users:
    user_ids.append(user['user_id'])
    names.append(user['name'])
    review_counts.append(user['review_count'])
    yelping_sinces.append(user['yelping_since'])
    usefuls.append(user['useful'])
    funnys.append(user['funny'])
    cools.append(user['cool'])
    elites.append(user['elite'])
    friendss.append(user['friends'])

# %%
business_food = []
food_id = []
food_latitude = []
food_longtitude = []

for i in range(0,len(business_categories)):
    if (not business_categories[i]==None) and ("food" in business_categories[i].lower() or "restaurant" in business_categories[i].lower()):
        business_food.append(i)
        food_id.append(business_ids[i])
        food_latitude.append(latitudes[i])
        food_longtitude.append(longtitudes[i])

# %%
np_food_id = np.array(food_id)
np_review_business_id = np.array(review_business_ids)
np_review_user_ids = np.array(review_user_ids)
np_user_ids = np.array(user_ids)

# %%
with open("location_as_label", 'w') as f:
    for i in range(0, len(food_id)):
        if i % 500 == 0:
            #break
            print(i)
        #index = review_business_ids.index(food_id[i])
        #indices = np.where(np_review_business_id==food_id[i])[0]
        #print(indices)
        #print(",".join(map(str, sorted((np_user_ids[:,None] == np_review_user_ids[indices]).argmax(axis=0)))))
        #print(i)
        #print(",".join(map(str, np.in1d(np_user_ids,np_review_user_ids[indices]).nonzero()[0])))
        #print(",".join(map(str, np_review_user_ids[indices])))
        #print("\n")
        #f.write(",".join(map(str, np_review_user_ids[indices])))
        #print(",".join(map(str, np.in1d(np_user_ids,np_review_user_ids[indices]).nonzero()[0])))
        f.write(str(food_latitude[i]))
        f.write(",")
        f.write(str(food_longtitude[i]))
        f.write('\n')
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# ...

# %%
with open("restaurant_as_hyperedge", 'w') as f:
    for i in range(0, len(business_food)):
        if i % 250 == 0:
            #break
            print(i)
        #index = review_business_ids.index(food_id[i])
        #indices = np.where(np_review_business_id==food_id[i])[0]
        indices = np.in1d(np_review_business_id,food_id[i]).nonzero()[0]
        #print(indices)
        #print(",".join(map(str, sorted((np_user_ids[:,None] == np_review_user_ids[indices]).argmax(axis=0)))))
        #print(i)
        #print(",".join(map(str, np.in1d(np_user_ids,np_review_user_ids[indices]).nonzero()[0])))
        #print(",".join(map(str, np_review_user_ids[indices])))
        #print("\n")
        #f.write(",".join(map(str, np_review_user_ids[indices])))
        #print(",".join(map(str, np.in1d(np_user_ids,np_review_user_ids[indices]).nonzero()[0])))
        f.write(",".join(map(str, np.in1d(np_user_ids,np_review_user_ids[indices]).nonzero()[0])))
        f.write('\n')
# Out:
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 5000
# 5250
# 5500
# 5750
# 6000
# 6250
# 6500
# 6750
# 7000
# 7250
# 7500
# 7750
# 8000
# 8250
# 8500
# 8750
# 9000
# 9250
# 9500
# 9750
# 10000
# 10250
# 10500
# 10750
# 11000
# 11250
# 11500
# 11750
# 12000
# 12250
# 12500
# 12750
# 13000
# 13250
# 13500
# 13750
# 14000
# 14250
# 14500
# 14750
# 15000
# 15250
# 15500
# 15750
# 16000
# 16250
# 16500
# 16750
# 17000
# 17250
# 17500
# 17750
# 18000
# 18250
# 18500
# 18750
# 19000
# 19250
# 19500
# 19750
# 20000
# 20250
# 20500
# 20750
# 21000
# 21250
# 21500
# 21750
# 22000
# 22250
# 22500
# 22750
# 23000
# 23250
# 23500
# 23750
# 24000
# 24250
# 24500
# 24750
# 25000
# 25250
# 25500
# 25750
# 26000
# 26250
# 26500
# 26750
# 27000
# 27250
# 27500
# 27750
# 28000
# 28250
# 28500
# 28750
# 29000
# 29250
# 29500
# 29750
# 30000
# 30250
# 30500
# 30750
# 31000
# 31250
# 31500
# 31750
# 32000
# 32250
# ...

# %%
food_id[0]
review_business_ids.index('MTSW4McQd7CbVtyjqoe9mw')
review_user_ids[3988]
user_ids.index('6_SpY41LIHZuIaiDs5FMKA')
# Out:
# 104922

# %%
len(np.where(np.array([2,3,2,41,34,2])==2)[0])
# Out:
# 3

# %%
len(set(user_ids)0)
# Out:
# 1987897
